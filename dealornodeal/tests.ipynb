# %%
# !pip install open_spiel
# !pip install numpy
# !pip install matplotlib
# Out:
# ...
#   Using cached open_spiel-1.6.8.tar.gz (5.4 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached scipy-1.16.3-cp311-cp311-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached ml_collections-1.1.0-py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached pyyaml-6.0.3-cp311-cp311-win_amd64.whl.metadata (2.4 kB)
# Using cached absl_py-2.3.1-py3-none-any.whl (135 kB)
# Using cached attrs-25.4.0-py3-none-any.whl (67 kB)
# Using cached ml_collections-1.1.0-py3-none-any.whl (76 kB)
# Using cached scipy-1.16.3-cp311-cp311-win_amd64.whl (38.7 MB)
# ...

# %%
from helpers import run_cfr, run_efr, run_cfr_regret, run_efr_regret
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from helpers import run_cfr, run_efr, run_cfr_regret, run_efr_regret
#
# File c:\Users\mason\OneDrive\Documents\vscworkspace\masters_thesis\dealornodeal\helpers.py:3
#       1 #main.py
# ----> 3 from open_spiel.python.algorithms import efr, cfr
#       4 import dealornodeal.games.deal_or_no_deal as deal_or_no_deal, dealornodeal.games.deal_or_no_deal_zerosum as deal_or_no_deal_zerosum
#       5 import dealornodeal.games.deal_or_no_deal_mini as deal_or_no_deal_mini, dealornodeal.games.deal_or_no_deal_mini_zerosum as deal_or_no_deal_mini_zerosum
#
# ModuleNotFoundError: No module named 'open_spiel'
